# %%
#Chapter 4

#4.1
#This one wasn't too hard. It was just a bit awkward to code as I had to make sure I coded it right.
secret = 9;
guess = 10;
if guess == secret:
    print("Just right.")
elif guess <= secret:
    print("Too low.")
else:
    print("Too high.")

#4.2
#This one I thought I was doing wrong at first and had to keep looking at the exercise to make sure I understood what I had to do.
#Turns out I did understand and it took me a bit of time to code.
small = True;
green = False;

if small:
    if green:
        print("It's a pea.")
    else:
        print("It's a cherry.")
else:
    if green:
        print("It's a watermelon.")
    else:
        print("It's a pumpkin.")


#Chapter 6

#6.1
#This one I had to work on last as I had trouble with it from the start.
#I had to go to Geeks For Geeks (https://www.geeksforgeeks.org/iterate-over-a-list-in-python/) to help me with this one.
list = [0, 1, 2, 3]
[print(i) for i in list]

#6.2
#This took me longer than I would like to admit. I did have to look up how to do a while loop to get an understanding of how to do it.
#It didn't as long to do it after looking up what to do from W3 Schools.
guess_me = 7;
number = 1;
while number < guess_me:
    print("Too low.");
    number += 1;
    if number == guess_me:
        print("Just right.");
        number += 1;
    if number > guess_me:
        print("Oops.");
        break;

#6.3
#Since this one and 6.2 were basically the same things, I copied 6.2 and put it here while adjucting the code to make sure it would work for 6.3.
guess_me2 = 5;
number2 = 1;
while number2 < guess_me2:
    print("Too low.");
    number2 += 1;
    if number2 == guess_me2:
        print("Just right.");
        number2 += 1;
    if number2 > guess_me2:
        print("Oops.");
        break;
# Out:
# Too high.
# It's a cherry.
# 0
# 1
# 2
# 3
# Too low.
# Too low.
# Too low.
# Too low.
# Too low.
# Too low.
# Just right.
# Oops.
# Too low.
# Too low.
# Too low.
# Too low.
# Just right.
# Oops.
